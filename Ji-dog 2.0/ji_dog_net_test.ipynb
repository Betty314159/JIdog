# %%
import torch
import gym

import numpy as np

# from ji_dog_net_v1 import PPO_Clip
# from ji_dog_net_v1 import ActorCritic_Clip
# from ji_dog_net_v1 import process_state

from ji_dog_net_v2 import PPO_Penalty
from ji_dog_net_v2 import ActorCritic_Penalty

from ji_dog_net_v3 import PPO_Clip
from ji_dog_net_v3 import ActorCritic_Clip
from ji_dog_net_v3 import process_state

# %% [markdown]
# ## Check device

# %%
print("============================================================================================")
# set device to cpu or cuda
device = torch.device('cpu')
if(torch.cuda.is_available()): 
    device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(device)))
else:
    print("Device set to : cpu")
print("============================================================================================")
# Out:
# ============================================================================================
# Device set to : NVIDIA GeForce RTX 4060 Laptop GPU
# ============================================================================================

# %% [markdown]
# ## Test ACNet

# %%
from torchviz import make_dot
state_dim = 20  
action_dim = 4 
ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)
state = torch.rand((state_dim,)).to(device)  
action, action_logprob, hidden_actor = ppo.policy.act(state)

print("Action output:", action)
print("Action log probability:", action_logprob)

state_value = ppo.policy.evaluate_critic(state)

print("State value output:", state_value)

ppo.buffer.rewards.append(1.0)
ppo.buffer.is_terminals.append(False)
# Out:
# Action output: tensor([[-1.0820,  1.0640, -0.1664,  0.0594]], device='cuda:0')
# Action log probability: tensor([-4.9043], device='cuda:0')
# State value output: tensor([0.0492], device='cuda:0', grad_fn=<ViewBackward0>)

# %%
from torchviz import make_dot
state_dim = 20  
action_dim = 4 
ppo = PPO_Penalty(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2, kl_target=0.01, kl_penalty_coef=0.5, action_std_init=0.6)
state = torch.rand((state_dim,)).to(device)  
action, action_logprob, hidden_actor = ppo.policy.act(state)

print("Action output:", action)
print("Action log probability:", action_logprob)

state_value = ppo.policy.evaluate_critic(state)

print("State value output:", state_value)

ppo.buffer.rewards.append(1.0)
ppo.buffer.is_terminals.append(False)
# Out:
# Action output: tensor([[ 0.7156, -1.7127, -0.0953, -0.1270]], device='cuda:0')
# Action log probability: tensor([-6.2792], device='cuda:0')
# State value output: tensor([-0.0212], device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# ## Test PPO _ v1

# %%
# from isaacsim import SimulationApp
# simulation_app = SimulationApp({"headless": False})

# from torch.utils.tensorboard import SummaryWriter

# from ji_dog_env_create import Ji_Dog_Env
# from tqdm import tqdm  
# import numpy as np
# import os


# # Load the saved model
# load_path = "Model_Checkpoints/Ji_dog_1.0_Episode.pth"
# ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)
# ppo.load(load_path)


# env = Ji_Dog_Env('Model(including video)/ji_dog1.0.usd')
# state_dim = 20
# action_dim = 4
# max_training_timesteps = 100
# max_timesteps = 500
# ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)

# # Initialize 
# writer = SummaryWriter(log_dir="runs/Ji_Dog_Training")


# state = env.reset()
# state = process_state(state)
# state = np.array(state)

# for t in range(max_timesteps + 1):
#     action = ppo.select_action(state)
#     state, reward, done, _ = env.step(action[0])
#     state = process_state(state)
#     state = np.array(state)
#     ppo.buffer.rewards.append(reward)
#     ppo.buffer.is_terminals.append(done)

#     if done:
#         break
# ppo.buffer.clear()                    
# # Update PPO and record metrics
# average_loss, policy_loss, value_loss, policy_entropy = ppo.update()

# %%
simulation_app.close()

# %% [markdown]
# ## Test PPO _ v3

# %%
from isaacsim import SimulationApp
simulation_app = SimulationApp({"headless": False})

from torch.utils.tensorboard import SummaryWriter

from ji_dog_env_create_v3 import Ji_Dog_Env
from tqdm import tqdm  
import numpy as np
import os



# Load the saved model
load_path = "Model_Checkpoints/Ji_dog_4.0_Episode.pth"
ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)
ppo.load(load_path)


env = Ji_Dog_Env('Model(including video)/ji_dog1.0.usd')


state_dim = 20
action_dim = 4
max_training_timesteps = 100
max_timesteps = 5000
# ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)

# Initialize 

writer = SummaryWriter(log_dir="runs/Ji_Dog_Training")
    
total_rewards = {
    "distance_reward": 0,
    "fall_penalty": 0,
    "symmetry_reward": 0,
    "period_penalty": 0,
    "contact_penalty": 0,
    "smoothness_penalty": 0,
    "progress_reward":0,
    "mass_centre_reward":0,
    "stability_penalty":0,
}

state = env.reset()
state = process_state(state)
state = np.array(state)

total_episode_reward = 0
# for ep in range(1, total_test_episodes+1):    
for t in range(max_timesteps + 1):
    action = ppo.select_action(state)
    state, total_reward, rewards, done, _ = env.step(action[0])

    state = process_state(state)
    state = np.array(state)
    # ppo.buffer.rewards.append(total_reward)
    # ppo.buffer.is_terminals.append(done)
    # ppo.buffer.reward_contributions.append(rewards) 
    
    # reward, reward_contributions = env.calculate_reward()
    for key in rewards:
        total_rewards[key] += rewards[key]

    
    total_episode_reward += total_reward
    if done:
        break
ppo.buffer.clear()        
# Update PPO and record metrics
# average_loss, policy_loss, value_loss, policy_entropy = ppo.update()


simulation_app.close()
# Out:
# Starting kit application with the following args:  ['/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/exts', '--ext-folder', '/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/apps', '--/physics/cudaDevice=0', '--portable']
# Passing the following args to the base kit application:  ['-f', '/home/bai/.local/share/jupyter/runtime/kernel-0ced6b96-6d02-4806-b483-22db30b724aa.json']
# [Warning] [omni.isaac.kit.simulation_app] Non-headless mode not supported with jupyter notebooks
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Info] [carb] Logging to file: /home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/kit/logs/Kit/Isaac-Sim/4.2/kit_20241122_190515.log
# 2024-11-22 11:05:15 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.086s] [ext: omni.blobkey-1.1.2] startup
# [0.087s] [ext: omni.kit.async_engine-0.0.1] startup
# [0.376s] [ext: omni.stats-1.0.1] startup
# [0.377s] [ext: omni.datastore-0.0.0] startup
# [0.381s] [ext: omni.client-1.2.0] startup
# [0.401s] [ext: omni.ujitso.default-1.0.0] startup
# [0.401s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.403s] [ext: omni.hsscclient-1.1.1] startup
# [0.403s] [ext: omni.assets.plugins-0.0.0] startup
# [0.404s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.408s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.417s] [ext: omni.kit.renderer.init-0.0.0] startup
# 2024-11-22 11:05:16 s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: Intel(R) Graphics (RPL-P)
# 2024-11-22 11:05:16 s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: Intel(R) Graphics (RPL-P)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.183.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060 Laptop.. | Yes: 0 |     | 8188    MB | 10de      | 0          |
# |     |                                  |        |     |            | 28e0      | 68c71b6b.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | Intel(R) Graphics (RPL-P)        |        |     | 23863   MB | 8086      | 0          |
# |     |                                  |        |     |            | a7a0      | 8680a0a7.. |
# |     |                                  |        |     |            | 0         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-49-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: 13th Gen Intel(R) Core(TM) i9-13900H | Cores: 14 | Logical: 28
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31817 | Free Memory: 12424
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 1980
# |---------------------------------------------------------------------------------------------|
# 2024-11-22 11:05:16 s] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# [0.833s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.834s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.834s] [ext: omni.pip.compute-1.4.0] startup
# [0.834s] [ext: omni.pip.cloud-1.1.3] startup
# [0.836s] [ext: omni.isaac.core_archive-2.3.0] startup
# [0.836s] [ext: omni.materialx.libs-1.0.4] startup
# [0.842s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [0.842s] [ext: omni.kit.telemetry-0.5.0] startup
# [0.867s] [ext: omni.usd.config-1.0.4] startup
# [0.871s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.871s] [ext: omni.usd.libs-1.0.1] startup
# [0.960s] [ext: omni.iray.libs-0.0.0] startup
# [0.964s] [ext: omni.mdl.neuraylib-0.2.8] startup
# [0.966s] [ext: omni.mdl-55.0.1] startup
# [0.983s] [ext: omni.kit.usd.mdl-1.0.1] startup
# [1.090s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [1.091s] [ext: omni.kit.test-1.1.0] startup
# [1.112s] [ext: omni.appwindow-1.1.8] startup
# [1.209s] [ext: omni.kit.renderer.core-1.0.2] startup
# [1.702s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.703s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [1.815s] [ext: omni.ui-2.25.22] startup
# [1.824s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.824s] [ext: carb.audio-0.1.0] startup
# [1.827s] [ext: omni.uiaudio-1.0.0] startup
# [1.828s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.828s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [1.835s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.838s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.858s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.860s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.862s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.868s] [ext: omni.anim.navigation.schema-106.1.0] startup
# [1.870s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [1.871s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.878s] [ext: omni.anim.graph.schema-106.1.0] startup
# [1.883s] [ext: omni.usd.schema.physx-106.1.9] startup
# [1.908s] [ext: omni.usd.schema.forcefield-106.1.9] startup
# [1.913s] [ext: omni.graph.exec-0.9.4] startup
# [1.914s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.914s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.915s] [ext: omni.kit.exec.core-0.13.4] startup
# [1.918s] [ext: omni.usd_resolver-1.0.0] startup
# [1.921s] [ext: omni.kit.commands-1.4.9] startup
# [1.923s] [ext: omni.activity.core-1.0.1] startup
# [1.924s] [ext: omni.usd.core-1.4.1] startup
# [1.927s] [ext: omni.resourcemonitor-105.0.1] startup
# [1.928s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.931s] [ext: omni.timeline-1.0.10] startup
# [1.933s] [ext: omni.kit.widget.nucleus_connector-1.1.9] startup
# [1.934s] [ext: usdrt.scenegraph-7.5.0] startup
# [1.965s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [1.966s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [1.979s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [1.983s] [ext: omni.usd-1.12.2] startup
# [2.019s] [ext: omni.kit.menu.core-1.0.4] startup
# [2.020s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [2.020s] [ext: omni.kit.property.adapter.core-1.0.1] startup
# [2.022s] [ext: omni.kit.menu.utils-1.5.27] startup
# [2.026s] [ext: omni.kit.clipboard-1.0.4] startup
# [2.027s] [ext: omni.kit.collaboration.channel_manager-1.0.12] startup
# [2.027s] [ext: omni.kit.property.adapter.usd-1.0.1] startup
# [2.028s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [2.030s] [ext: omni.kit.widget.graph-1.12.15] startup
# [2.033s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [2.034s] [ext: omni.kit.widget.filter-1.1.4] startup
# [2.034s] [ext: omni.kit.property.adapter.fabric-1.0.1] startup
# [2.035s] [ext: omni.ui_query-1.1.4] startup
# [2.035s] [ext: omni.kit.window.extensions-1.4.11] startup
# [2.039s] [ext: omni.kit.usd.layers-2.1.36] startup
# [2.045s] [ext: omni.kit.widget.context_menu-1.2.2] startup
# [2.045s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [2.046s] [ext: omni.kit.notification_manager-1.0.9] startup
# [2.047s] [ext: omni.kit.hotkeys.core-1.3.5] startup
# [2.047s] [ext: omni.kit.context_menu-1.8.1] startup
# [2.048s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [2.049s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [2.050s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [2.050s] [ext: omni.kit.widget.filebrowser-2.10.51] startup
# [2.053s] [ext: omni.kit.search_core-1.0.5] startup
# [2.053s] [ext: omni.kit.widget.path_field-2.0.10] startup
# [2.054s] [ext: omni.ui.scene-1.10.3] startup
# [2.057s] [ext: omni.kit.widget.search_delegate-1.0.5] startup
# [2.058s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [2.058s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [2.058s] [ext: omni.volume-0.5.0] startup
# [2.061s] [ext: omni.kit.window.filepicker-2.10.40] startup
# [2.066s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [2.067s] [ext: omni.kit.window.file_exporter-1.0.30] startup
# [2.068s] [ext: omni.ujitso.client-0.0.0] startup
# [2.068s] [ext: omni.kit.widget.stage-2.11.2] startup
# [2.075s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [2.076s] [ext: omni.kit.collaboration.presence_layer-1.0.9] startup
# [2.077s] [ext: omni.hydra.rtx-1.0.0] startup
# [2.092s] [ext: omni.inspect-1.0.1] startup
# [2.093s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [2.093s] [ext: omni.kit.window.file_importer-1.1.12] startup
# [2.094s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [2.095s] [ext: omni.kit.widget.settings-1.2.2] startup
# [2.096s] [ext: omni.kit.window.file-1.3.54] startup
# [2.098s] [ext: omni.kit.window.drop_support-1.0.3] startup
# [2.098s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [2.098s] [ext: omni.kit.window.preferences-1.6.0] startup
# [2.103s] [ext: omni.kit.window.content_browser-2.9.18] startup
# [2.112s] [ext: omni.kit.widget.live_session_management-1.2.20] startup
# [2.113s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [2.114s] [ext: omni.kit.hydra_texture-1.3.9] startup
# [2.117s] [ext: omni.kit.viewport.legacy_gizmos-1.1.0] startup
# [2.119s] [ext: omni.kit.raycast.query-1.0.5] startup
# [2.123s] [ext: omni.kit.material.library-1.5.6] startup
# [2.128s] [ext: omni.kit.widget.viewport-106.1.0] startup
# [2.130s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [2.130s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [2.132s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [2.133s] [ext: omni.kit.viewport.window-107.0.6] startup
# [2.144s] [ext: omni.kit.window.property-1.11.3] startup
# [2.145s] [ext: omni.graph.core-2.179.2] startup
# [2.146s] [ext: omni.graph.tools-1.79.0] startup
# [2.159s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [2.160s] [ext: omni.kit.property.usd-4.2.8] startup
# [2.166s] [ext: omni.debugdraw-0.1.3] startup
# [2.169s] [ext: omni.graph-1.140.0] startup
# [2.200s] [ext: omni.graph.ui-1.70.2] startup
# [2.212s] [ext: omni.kvdb-106.1.9] startup
# [2.214s] [ext: omni.graph.image.core-0.4.5] startup
# [2.216s] [ext: omni.localcache-106.1.9] startup
# [2.217s] [ext: omni.graph.image.nodes-1.1.0] startup
# [2.220s] [ext: omni.usdphysics-106.1.9] startup
# [2.223s] [ext: omni.physx.foundation-106.1.9] startup
# [2.224s] [ext: omni.convexdecomposition-106.1.9] startup
# [2.228s] [ext: omni.graph.nodes-1.146.1] startup
# [2.236s] [ext: omni.physx.cooking-106.1.9] startup
# [2.245s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [2.247s] [ext: omni.physx-106.1.9] startup
# [2.258s] [ext: omni.kit.stage_templates-1.2.5] startup
# [2.260s] [ext: omni.isaac.version-1.1.0] startup
# [2.260s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [2.262s] [ext: omni.isaac.nucleus-0.3.1] startup
# [2.263s] [ext: omni.physics.tensors-106.1.9] startup
# [2.268s] [ext: omni.physx.stageupdate-106.1.9] startup
# [2.270s] [ext: omni.graph.action_core-1.1.6] startup
# [2.273s] [ext: omni.warp.core-1.2.1] startup
# [2.337s] [ext: omni.physx.tensors-106.1.9] startup
# [2.341s] [ext: omni.graph.scriptnode-1.20.1] startup
# [2.342s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [2.344s] [ext: omni.graph.action_nodes-1.24.0] startup
# [2.351s] [ext: omni.kit.ui_test-1.3.2] startup
# [2.355s] [ext: omni.isaac.core-3.19.5] startup
# [2.607s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [2.612s] [ext: omni.graph.action-1.102.1] startup
# [2.614s] [ext: omni.kit.window.cursor-1.1.2] startup
# [2.616s] [ext: omni.isaac.ui-0.16.0] startup
# [2.620s] [ext: omni.kit.viewport.menubar.core-106.1.0] startup
# [2.633s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [2.635s] [ext: omni.syntheticdata-0.6.9] startup
# [2.655s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [2.657s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [2.661s] [ext: omni.kit.numpy.common-0.1.2] startup
# [2.663s] [ext: omni.warp-1.2.1] startup
# [2.669s] [ext: omni.kit.window.material_graph-1.8.18] startup
# [2.692s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [2.721s] [ext: omni.replicator.core-1.11.20] startup
# 2024-11-22 11:05:18 [2,694ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# Warp 1.2.1 initialized:
#    CUDA Toolkit 11.8, Driver 12.2
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4060 Laptop GPU" (8 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/bai/.cache/warp/1.2.1
# [2.833s] [ext: omni.isaac.lula-3.0.1] startup
# [2.840s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [2.844s] [ext: omni.isaac.core_nodes-1.16.3] startup
# [2.862s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [2.875s] [ext: omni.isaac.manipulators-2.1.0] startup
# [2.882s] [ext: omni.isaac.franka-0.4.1] startup
# [2.890s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [2.894s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [2.906s] [ext: omni.isaac.cortex-0.3.9] startup
# [2.908s] [ext: omni.graph.window.core-1.113.1] startup
# [2.939s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [2.952s] [ext: omni.isaac.cortex.sample_behaviors-1.0.6] startup
# [2.954s] [ext: omni.graph.window.generic-1.26.0] startup
# [2.967s] [ext: omni.isaac.menu-0.7.3] startup
# [2.978s] [ext: omni.kit.widget.live-2.1.8] startup
# [2.983s] [ext: omni.kit.actions.window-1.1.1] startup
# [2.988s] [ext: omni.kit.widget.cache_indicator-2.0.10] startup
# [3.062s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# 2024-11-22 11:05:18 [3,002ms] [Warning] [omni.kit.widget.cache_indicator.cache_state_menu] Unable to detect Omniverse Cache Server. Consider installing it for better IO performance.
# [3.071s] [ext: omni.kit.ui.actions-1.0.2] startup
# [3.072s] [ext: omni.kit.widget.stage_icons-1.0.5] startup
# [3.073s] [ext: omni.kit.menu.common-1.1.7] startup
# [3.074s] [ext: omni.kit.selection-0.1.4] startup
# [3.076s] [ext: omni.isaac.kit-1.13.2] startup
# [3.076s] [ext: omni.isaac.block_world-1.0.0] startup
# [3.078s] [ext: omni.kit.window.stage-2.5.10] startup
# [3.082s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [3.086s] [ext: omni.kit.menu.edit-1.1.24] startup
# [3.091s] [ext: omni.kit.menu.file-1.1.14] startup
# [3.092s] [ext: omni.kit.profiler.window-2.2.3] startup
# [3.096s] [ext: omni.kit.menu.stage-1.2.5] startup
# [3.098s] [ext: omni.isaac.occupancy_map-1.0.3] startup
# [3.104s] [ext: omni.importer.mjcf-1.1.1] startup
# [3.113s] [ext: omni.graph.window.action-1.28.0] startup
# [3.119s] [ext: omni.kit.property.camera-1.0.8] startup
# [3.120s] [ext: omni.kit.property.light-1.0.10] startup
# [3.122s] [ext: omni.kit.property.geometry-1.3.1] startup
# [3.125s] [ext: omni.hydra.scene_api-0.1.2] startup
# [3.129s] [ext: omni.kit.property.audio-1.0.14] startup
# [3.132s] [ext: omni.kit.property.render-1.1.2] startup
# [3.133s] [ext: omni.kit.property.transform-1.5.9] startup
# [3.136s] [ext: omni.kit.property.material-1.10.8] startup
# [3.140s] [ext: omni.kit.widget.layers-1.8.0] startup
# [3.149s] [ext: omni.kit.property.isaac-0.2.3] startup
# [3.150s] [ext: omni.kit.property.bundle-1.3.1] startup
# [3.151s] [ext: omni.sensors.nv.common-1.2.2-isaac-1] startup
# [3.160s] [ext: omni.kit.property.layer-1.1.8] startup
# [3.162s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [3.164s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [3.165s] [ext: omni.sensors.nv.materials-1.2.1-isaac-1] startup
# [3.167s] [ext: omni.sensors.nv.wpm-1.2.1-isaac-1] startup
# [3.168s] [ext: omni.kit.viewport.actions-106.0.2] startup
# [3.171s] [ext: omni.sensors.nv.lidar-1.2.2-isaac-1] startup
# [3.176s] [ext: omni.sensors.nv.radar-1.2.1-isaac-1] startup
# [3.184s] [ext: omni.kit.viewport.menubar.display-107.0.2] startup
# [3.185s] [ext: omni.kit.manipulator.transform-104.7.4] startup
# [3.188s] [ext: omni.kit.widget.toolbar-1.7.2] startup
# [3.193s] [ext: omni.sensors.tiled-0.0.6] startup
# [3.195s] [ext: omni.sensors.nv.ids-1.1.0-isaac-1] startup
# [3.199s] [ext: omni.isaac.range_sensor-3.1.2] startup
# [3.209s] [ext: omni.usdphysics.ui-106.1.9] startup
# [3.226s] [ext: omni.physx.commands-106.1.9] startup
# [3.229s] [ext: omni.kit.manipulator.tool.snap-1.5.11] startup
# [3.233s] [ext: omni.isaac.sensor-12.9.1] startup
# [3.283s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [3.287s] [ext: omni.physx.ui-106.1.9] startup
# [3.315s] [ext: omni.isaac.quadruped-2.0.1] startup
# [3.321s] [ext: omni.kit.viewport.manipulator.transform-107.0.2] startup
# [3.325s] [ext: omni.physx.demos-106.1.9] startup
# [3.340s] [ext: omni.kit.property.physx-106.1.9] startup
# [3.404s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [3.406s] [ext: omni.kit.manipulator.prim.core-107.0.4] startup
# [3.410s] [ext: omni.fabric.commands-1.1.5] startup
# [3.413s] [ext: omni.physx.vehicle-106.1.9] startup
# [3.427s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [3.433s] [ext: omni.kit.manipulator.prim.fabric-107.0.3] startup
# [3.436s] [ext: omni.kit.manipulator.prim.usd-107.0.2] startup
# [3.437s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [3.439s] [ext: omni.kit.window.commands-0.2.6] startup
# [3.441s] [ext: omni.physx.camera-106.1.9] startup
# [3.449s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [3.452s] [ext: omni.kit.viewport.menubar.camera-107.0.2] startup
# [3.456s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [3.456s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [3.457s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [3.459s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [3.461s] [ext: omni.kit.viewport.menubar.render-106.1.1] startup
# [3.462s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [3.465s] [ext: omni.physx.cct-106.1.9] startup
# [3.475s] [ext: omni.physx.graph-106.1.9] startup
# [3.490s] [ext: omni.physx.supportui-106.1.9] startup
# [3.507s] [ext: omni.physx.telemetry-106.1.9] startup
# [3.510s] [ext: omni.graph.ui_nodes-1.26.0] startup
# [3.515s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [3.516s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [3.517s] [ext: omni.kit.window.console-0.2.13] startup
# [3.525s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [3.528s] [ext: omni.kit.menu.create-1.0.16] startup
# [3.529s] [ext: omni.graph.bundle.action-2.4.1] startup
# [3.531s] [ext: omni.physx.bundle-106.1.9] startup
# [3.532s] [ext: omni.rtx.window.settings-0.6.17] startup
# [3.536s] [ext: omni.kit.window.status_bar-0.1.7] startup
# [3.540s] [ext: omni.kit.window.title-1.1.5] startup
# [3.541s] [ext: omni.replicator.isaac-1.15.2] startup
# [3.559s] [ext: omni.replicator.replicator_yaml-2.0.6] startup
# [3.576s] [ext: omni.rtx.settings.core-0.6.3] startup
# [3.591s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [3.601s] [ext: semantics.schema.editor-0.3.8] startup
# [3.610s] [ext: semantics.schema.property-1.0.4] startup
# [3.613s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [3.613s] [ext: omni.isaac.utils-1.0.1] startup
# [3.615s] [ext: omni.isaac.cloner-0.8.1] startup
# [3.618s] [ext: omni.importer.urdf-1.14.1] startup
# [3.653s] [ext: omni.kit.window.stats-0.1.6] startup
# [3.654s] [ext: omni.isaac.sim.python-4.2.0] startup
# [3.655s] Simulation App Starting
# [5.079s] app ready
# [5.979s] Simulation App Startup Complete
# /home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/Ji-dog 2.0/ji_dog_net_v3.py:276: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.policy_old.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))
# /home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/Ji-dog 2.0/ji_dog_net_v3.py:277: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.policy.load_state_dict(torch.load(checkpoint_path, map_location=lambda storage, loc: storage))
# Robot articulation successfully loaded: <omni.isaac.core.robots.robot.Robot object at 0x74547fde2fe0>
