# %%
import torch
import gym

import numpy as np

from ji_dog_net_v1 import PPO_Clip
from ji_dog_net_v1 import ActorCritic_Clip
from ji_dog_net_v1 import process_state

from ji_dog_net_v2 import PPO_Penalty
from ji_dog_net_v2 import ActorCritic_Penalty

# from ji_dog_net_v3 import PPO_Clip
# from ji_dog_net_v3 import ActorCritic_Clip
# from ji_dog_net_v3 import process_state

# %% [markdown]
# ## Check device

# %%
print("============================================================================================")
# set device to cpu or cuda
device = torch.device('cpu')
if(torch.cuda.is_available()): 
    device = torch.device('cuda:0') 
    torch.cuda.empty_cache()
    print("Device set to : " + str(torch.cuda.get_device_name(device)))
else:
    print("Device set to : cpu")
print("============================================================================================")
# Out:
# ============================================================================================
# Device set to : NVIDIA GeForce RTX 4060 Laptop GPU
# ============================================================================================

# %% [markdown]
# ## Test ACNet

# %%
from torchviz import make_dot
state_dim = 20  
action_dim = 4 
ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)
state = torch.rand((state_dim,)).to(device)  
action, action_logprob, hidden_actor = ppo.policy.act(state)

print("Action output:", action)
print("Action log probability:", action_logprob)

state_value = ppo.policy.evaluate_critic(state)

print("State value output:", state_value)

ppo.buffer.rewards.append(1.0)
ppo.buffer.is_terminals.append(False)
# Out:
# Action output: tensor([[ 0.3450, -0.7188, -0.6027,  0.9508]], device='cuda:0')
# Action log probability: tensor([-4.0740], device='cuda:0')
# State value output: tensor([-0.0086], device='cuda:0', grad_fn=<ViewBackward0>)

# %%
from torchviz import make_dot
state_dim = 20  
action_dim = 4 
ppo = PPO_Penalty(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2, kl_target=0.01, kl_penalty_coef=0.5, action_std_init=0.6)
state = torch.rand((state_dim,)).to(device)  
action, action_logprob, hidden_actor = ppo.policy.act(state)

print("Action output:", action)
print("Action log probability:", action_logprob)

state_value = ppo.policy.evaluate_critic(state)

print("State value output:", state_value)

ppo.buffer.rewards.append(1.0)
ppo.buffer.is_terminals.append(False)
# Out:
# Action output: tensor([[-0.3113,  0.8865,  0.2939,  0.5635]], device='cuda:0')
# Action log probability: tensor([-3.4099], device='cuda:0')
# State value output: tensor([0.0464], device='cuda:0', grad_fn=<ViewBackward0>)

# %% [markdown]
# ## Train PPO

# %%
# Environment and simulation setup
from isaacsim import SimulationApp
simulation_app = SimulationApp({"headless": True})

from torch.utils.tensorboard import SummaryWriter

from ji_dog_env_create import Ji_Dog_Env
from tqdm import tqdm  
import numpy as np
import os

if __name__ == "__main__":
    relative_path = "Model(including video)/ji_dog1.0.usd"
    env = Ji_Dog_Env(relative_path)
    state_dim = 20
    action_dim = 4
    max_training_timesteps = 1000
    max_timesteps = 5000
    ppo = PPO_Clip(state_dim, action_dim, lr_actor=0.0003, lr_critic=0.001, gamma=0.99, K_epochs=4, eps_clip=0.2)

    # Initialize 
    writer = SummaryWriter(log_dir="runs/Ji_Dog_Training1")

    for episode in tqdm(range(max_training_timesteps), desc="Training Episodes"):
        state = env.reset()
        state = process_state(state)
        state = np.array(state)
        episode_reward = 0
        for t in range(max_timesteps + 1):
            action = ppo.select_action(state)
            state, reward, done, _ = env.step(action[0])
            state = process_state(state)
            state = np.array(state)
            ppo.buffer.rewards.append(reward)
            ppo.buffer.is_terminals.append(done)
            episode_reward = episode_reward + reward
            if done:
                break
                    
        # Update PPO and record metrics
        average_loss, policy_loss, value_loss, policy_entropy = ppo.update()
        
        # Log metrics to TensorBoard
        writer.add_scalar("Average Loss", average_loss, episode)
        writer.add_scalar("Policy Entropy", policy_entropy, episode)
        writer.add_scalar("Value Loss", value_loss, episode)
        writer.add_scalar("Policy Loss", policy_loss, episode)
        writer.add_scalar("Episode Reward", episode_reward, episode)
        
        if episode % 10 == 0:
            print(f"Episode {episode} completed with reward: {episode_reward}")

    writer.close()

save_path = "Model_Checkpoints/Ji_dog_{}_Episode.pth".format('2.0')
print("save checkpoint path : " + save_path)
ppo.save(save_path)
print('Finished!')
# Out:
# Starting kit application with the following args:  ['/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/exts', '--ext-folder', '/home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--/app/window/hideUi=1']
# Passing the following args to the base kit application:  ['-f', '/home/bai/.local/share/jupyter/runtime/kernel-36ac2c6a-77fd-44ac-b91a-60b7492a66c4.json']
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Info] [carb] Logging to file: /home/bai/.local/share/ov/pkg/isaac-sim-4.2.0/kit/logs/Kit/Isaac-Sim/4.2/kit_20241122_183934.log
# 2024-11-22 10:39:34 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.078s] [ext: omni.blobkey-1.1.2] startup
# [0.078s] [ext: omni.kit.async_engine-0.0.1] startup
# [0.336s] [ext: omni.stats-1.0.1] startup
# [0.337s] [ext: omni.datastore-0.0.0] startup
# [0.340s] [ext: omni.client-1.2.0] startup
# [0.357s] [ext: omni.ujitso.default-1.0.0] startup
# [0.357s] [ext: omni.gpu_foundation.shadercache.vulkan-1.0.0] startup
# [0.359s] [ext: omni.hsscclient-1.1.1] startup
# [0.359s] [ext: omni.assets.plugins-0.0.0] startup
# [0.360s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.363s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.368s] [ext: omni.kit.renderer.init-0.0.0] startup
# 2024-11-22 10:39:34 s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: Intel(R) Graphics (RPL-P)
# 2024-11-22 10:39:34 s] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: Intel(R) Graphics (RPL-P)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.183.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060 Laptop.. | Yes: 0 |     | 8188    MB | 10de      | 0          |
# |     |                                  |        |     |            | 28e0      | 68c71b6b.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | Intel(R) Graphics (RPL-P)        |        |     | 23863   MB | 8086      | 0          |
# |     |                                  |        |     |            | a7a0      | 8680a0a7.. |
# |     |                                  |        |     |            | 0         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-49-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: 13th Gen Intel(R) Core(TM) i9-13900H | Cores: 14 | Logical: 28
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31817 | Free Memory: 12458
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 1980
# |---------------------------------------------------------------------------------------------|
# 2024-11-22 10:39:34 s] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# [0.771s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.772s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.772s] [ext: omni.pip.compute-1.4.0] startup
# [0.773s] [ext: omni.pip.cloud-1.1.3] startup
# [0.774s] [ext: omni.isaac.core_archive-2.3.0] startup
# [0.774s] [ext: omni.materialx.libs-1.0.4] startup
# [0.781s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [0.781s] [ext: omni.kit.telemetry-0.5.0] startup
# [0.808s] [ext: omni.usd.config-1.0.4] startup
# [0.811s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [0.812s] [ext: omni.usd.libs-1.0.1] startup
# [0.900s] [ext: omni.iray.libs-0.0.0] startup
# [0.904s] [ext: omni.mdl.neuraylib-0.2.8] startup
# [0.906s] [ext: omni.mdl-55.0.1] startup
# [0.923s] [ext: omni.kit.usd.mdl-1.0.1] startup
# [1.029s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [1.030s] [ext: omni.kit.test-1.1.0] startup
# [1.050s] [ext: omni.appwindow-1.1.8] startup
# [1.052s] [ext: omni.kit.renderer.core-1.0.2] startup
# [1.060s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.063s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [1.120s] [ext: omni.ui-2.25.22] startup
# [1.129s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.130s] [ext: carb.audio-0.1.0] startup
# [1.132s] [ext: omni.uiaudio-1.0.0] startup
# [1.133s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.133s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [1.139s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.142s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.161s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.165s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.167s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.174s] [ext: omni.anim.navigation.schema-106.1.0] startup
# [1.176s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [1.178s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.182s] [ext: omni.anim.graph.schema-106.1.0] startup
# [1.190s] [ext: omni.usd.schema.physx-106.1.9] startup
# [1.216s] [ext: omni.usd.schema.forcefield-106.1.9] startup
# [1.221s] [ext: omni.graph.exec-0.9.4] startup
# [1.222s] [ext: omni.kit.usd_undo-0.1.8] startup
# [1.222s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.223s] [ext: omni.kit.exec.core-0.13.4] startup
# [1.226s] [ext: omni.usd_resolver-1.0.0] startup
# [1.229s] [ext: omni.kit.commands-1.4.9] startup
# [1.231s] [ext: omni.activity.core-1.0.1] startup
# [1.233s] [ext: omni.usd.core-1.4.1] startup
# [1.235s] [ext: omni.resourcemonitor-105.0.1] startup
# [1.236s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [1.239s] [ext: omni.timeline-1.0.10] startup
# [1.241s] [ext: omni.kit.widget.nucleus_connector-1.1.9] startup
# [1.242s] [ext: usdrt.scenegraph-7.5.0] startup
# [1.274s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [1.275s] [ext: omni.hydra.usdrt_delegate-7.5.1] startup
# [1.288s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [1.292s] [ext: omni.usd-1.12.2] startup
# [1.331s] [ext: omni.kit.menu.core-1.0.4] startup
# [1.331s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [1.332s] [ext: omni.kit.property.adapter.core-1.0.1] startup
# [1.333s] [ext: omni.kit.menu.utils-1.5.27] startup
# [1.339s] [ext: omni.kit.clipboard-1.0.4] startup
# [1.339s] [ext: omni.kit.collaboration.channel_manager-1.0.12] startup
# [1.340s] [ext: omni.kit.property.adapter.usd-1.0.1] startup
# [1.340s] [ext: omni.kit.widget.options_menu-1.1.6] startup
# [1.343s] [ext: omni.kit.widget.graph-1.12.15] startup
# [1.347s] [ext: omni.kit.widget.searchfield-1.1.8] startup
# [1.347s] [ext: omni.kit.widget.filter-1.1.4] startup
# [1.348s] [ext: omni.kit.property.adapter.fabric-1.0.1] startup
# [1.349s] [ext: omni.ui_query-1.1.4] startup
# [1.349s] [ext: omni.kit.window.extensions-1.4.11] startup
# [1.353s] [ext: omni.kit.usd.layers-2.1.36] startup
# [1.361s] [ext: omni.kit.widget.context_menu-1.2.2] startup
# [1.361s] [ext: omni.hydra.rtx.shadercache.vulkan-1.0.0] startup
# [1.362s] [ext: omni.kit.notification_manager-1.0.9] startup
# [1.363s] [ext: omni.kit.hotkeys.core-1.3.5] startup
# [1.364s] [ext: omni.kit.context_menu-1.8.1] startup
# [1.365s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [1.366s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [1.367s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [1.367s] [ext: omni.kit.widget.filebrowser-2.10.51] startup
# [1.370s] [ext: omni.kit.search_core-1.0.5] startup
# [1.371s] [ext: omni.kit.widget.path_field-2.0.10] startup
# [1.371s] [ext: omni.ui.scene-1.10.3] startup
# [1.375s] [ext: omni.kit.widget.search_delegate-1.0.5] startup
# [1.376s] [ext: omni.kit.widget.options_button-1.0.3] startup
# [1.376s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [1.377s] [ext: omni.volume-0.5.0] startup
# [1.379s] [ext: omni.kit.window.filepicker-2.10.40] startup
# [1.385s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [1.386s] [ext: omni.kit.window.file_exporter-1.0.30] startup
# [1.388s] [ext: omni.ujitso.client-0.0.0] startup
# [1.388s] [ext: omni.kit.widget.stage-2.11.2] startup
# [1.396s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [1.397s] [ext: omni.kit.collaboration.presence_layer-1.0.9] startup
# [1.399s] [ext: omni.hydra.rtx-1.0.0] startup
# [1.416s] [ext: omni.inspect-1.0.1] startup
# [1.418s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [1.419s] [ext: omni.kit.window.file_importer-1.1.12] startup
# [1.420s] [ext: omni.kit.stage_template.core-1.1.22] startup
# [1.420s] [ext: omni.kit.widget.settings-1.2.2] startup
# [1.422s] [ext: omni.kit.window.file-1.3.54] startup
# [1.424s] [ext: omni.kit.window.drop_support-1.0.3] startup
# [1.424s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [1.425s] [ext: omni.kit.window.preferences-1.6.0] startup
# [1.430s] [ext: omni.kit.window.content_browser-2.9.18] startup
# [1.441s] [ext: omni.kit.widget.live_session_management-1.2.20] startup
# [1.442s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [1.444s] [ext: omni.kit.hydra_texture-1.3.9] startup
# [1.447s] [ext: omni.kit.viewport.legacy_gizmos-1.1.0] startup
# [1.450s] [ext: omni.kit.raycast.query-1.0.5] startup
# [1.455s] [ext: omni.kit.material.library-1.5.6] startup
# [1.460s] [ext: omni.kit.widget.viewport-106.1.0] startup
# [1.463s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [1.463s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [1.466s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [1.466s] [ext: omni.kit.viewport.window-107.0.6] startup
# [1.481s] [ext: omni.kit.window.property-1.11.3] startup
# [1.482s] [ext: omni.graph.core-2.179.2] startup
# [1.485s] [ext: omni.graph.tools-1.79.0] startup
# [1.500s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [1.501s] [ext: omni.kit.property.usd-4.2.8] startup
# [1.508s] [ext: omni.debugdraw-0.1.3] startup
# [1.511s] [ext: omni.graph-1.140.0] startup
# [1.545s] [ext: omni.graph.ui-1.70.2] startup
# [1.560s] [ext: omni.kvdb-106.1.9] startup
# [1.562s] [ext: omni.graph.image.core-0.4.5] startup
# [1.564s] [ext: omni.localcache-106.1.9] startup
# [1.566s] [ext: omni.graph.image.nodes-1.1.0] startup
# [1.569s] [ext: omni.usdphysics-106.1.9] startup
# [1.572s] [ext: omni.physx.foundation-106.1.9] startup
# [1.574s] [ext: omni.convexdecomposition-106.1.9] startup
# [1.579s] [ext: omni.graph.nodes-1.146.1] startup
# [1.587s] [ext: omni.physx.cooking-106.1.9] startup
# [1.598s] [ext: omni.kit.primitive.mesh-1.0.17] startup
# [1.601s] [ext: omni.physx-106.1.9] startup
# [1.613s] [ext: omni.kit.stage_templates-1.2.5] startup
# [1.615s] [ext: omni.isaac.version-1.1.0] startup
# [1.616s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [1.617s] [ext: omni.isaac.nucleus-0.3.1] startup
# [1.618s] [ext: omni.physics.tensors-106.1.9] startup
# [1.625s] [ext: omni.physx.stageupdate-106.1.9] startup
# [1.627s] [ext: omni.graph.action_core-1.1.6] startup
# [1.630s] [ext: omni.warp.core-1.2.1] startup
# [1.697s] [ext: omni.physx.tensors-106.1.9] startup
# [1.702s] [ext: omni.graph.scriptnode-1.20.1] startup
# [1.703s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [1.705s] [ext: omni.graph.action_nodes-1.24.0] startup
# [1.712s] [ext: omni.kit.ui_test-1.3.2] startup
# [1.717s] [ext: omni.isaac.core-3.19.5] startup
# [1.964s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [1.968s] [ext: omni.graph.action-1.102.1] startup
# [1.970s] [ext: omni.kit.window.cursor-1.1.2] startup
# [1.972s] [ext: omni.isaac.ui-0.16.0] startup
# [1.975s] [ext: omni.kit.viewport.menubar.core-106.1.0] startup
# [1.993s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [1.994s] [ext: omni.syntheticdata-0.6.9] startup
# [2.015s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [2.017s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [2.021s] [ext: omni.kit.numpy.common-0.1.2] startup
# [2.023s] [ext: omni.warp-1.2.1] startup
# [2.032s] [ext: omni.kit.window.material_graph-1.8.18] startup
# [2.054s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [2.061s] [ext: omni.replicator.core-1.11.20] startup
# 2024-11-22 10:39:36 [2,045ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# Warp 1.2.1 initialized:
#    CUDA Toolkit 11.8, Driver 12.2
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4060 Laptop GPU" (8 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/bai/.cache/warp/1.2.1
# [2.208s] [ext: omni.isaac.lula-3.0.1] startup
# [2.218s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [2.223s] [ext: omni.isaac.core_nodes-1.16.3] startup
# [2.242s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [2.276s] [ext: omni.isaac.manipulators-2.1.0] startup
# [2.291s] [ext: omni.isaac.franka-0.4.1] startup
# [2.295s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [2.300s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [2.307s] [ext: omni.isaac.cortex-0.3.9] startup
# [2.308s] [ext: omni.graph.window.core-1.113.1] startup
# [2.329s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [2.339s] [ext: omni.isaac.cortex.sample_behaviors-1.0.6] startup
# [2.343s] [ext: omni.graph.window.generic-1.26.0] startup
# [2.355s] [ext: omni.isaac.menu-0.7.3] startup
# [2.362s] [ext: omni.kit.widget.live-2.1.8] startup
# [2.366s] [ext: omni.kit.actions.window-1.1.1] startup
# [2.379s] [ext: omni.kit.widget.cache_indicator-2.0.10] startup
# [2.452s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# 2024-11-22 10:39:36 [2,394ms] [Warning] [omni.kit.widget.cache_indicator.cache_state_menu] Unable to detect Omniverse Cache Server. Consider installing it for better IO performance.
# [2.464s] [ext: omni.kit.ui.actions-1.0.2] startup
# [2.466s] [ext: omni.kit.widget.stage_icons-1.0.5] startup
# [2.468s] [ext: omni.kit.menu.common-1.1.7] startup
# [2.469s] [ext: omni.kit.selection-0.1.4] startup
# [2.471s] [ext: omni.isaac.kit-1.13.2] startup
# [2.473s] [ext: omni.isaac.block_world-1.0.0] startup
# [2.480s] [ext: omni.kit.window.stage-2.5.10] startup
# [2.484s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [2.488s] [ext: omni.kit.menu.edit-1.1.24] startup
# [2.492s] [ext: omni.kit.menu.file-1.1.14] startup
# [2.493s] [ext: omni.kit.profiler.window-2.2.3] startup
# [2.498s] [ext: omni.kit.menu.stage-1.2.5] startup
# [2.501s] [ext: omni.isaac.occupancy_map-1.0.3] startup
# [2.506s] [ext: omni.importer.mjcf-1.1.1] startup
# [2.512s] [ext: omni.graph.window.action-1.28.0] startup
# [2.518s] [ext: omni.kit.property.camera-1.0.8] startup
# [2.519s] [ext: omni.kit.property.light-1.0.10] startup
# [2.521s] [ext: omni.kit.property.geometry-1.3.1] startup
# [2.524s] [ext: omni.hydra.scene_api-0.1.2] startup
# [2.528s] [ext: omni.kit.property.audio-1.0.14] startup
# [2.531s] [ext: omni.kit.property.render-1.1.2] startup
# [2.532s] [ext: omni.kit.property.transform-1.5.9] startup
# [2.535s] [ext: omni.kit.property.material-1.10.8] startup
# [2.539s] [ext: omni.kit.widget.layers-1.8.0] startup
# [2.550s] [ext: omni.kit.property.isaac-0.2.3] startup
# [2.553s] [ext: omni.kit.property.bundle-1.3.1] startup
# [2.554s] [ext: omni.sensors.nv.common-1.2.2-isaac-1] startup
# [2.564s] [ext: omni.kit.property.layer-1.1.8] startup
# [2.566s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [2.568s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [2.568s] [ext: omni.sensors.nv.materials-1.2.1-isaac-1] startup
# [2.571s] [ext: omni.sensors.nv.wpm-1.2.1-isaac-1] startup
# [2.572s] [ext: omni.kit.viewport.actions-106.0.2] startup
# [2.576s] [ext: omni.sensors.nv.lidar-1.2.2-isaac-1] startup
# [2.583s] [ext: omni.sensors.nv.radar-1.2.1-isaac-1] startup
# [2.588s] [ext: omni.kit.viewport.menubar.display-107.0.2] startup
# [2.591s] [ext: omni.kit.manipulator.transform-104.7.4] startup
# [2.594s] [ext: omni.kit.widget.toolbar-1.7.2] startup
# [2.599s] [ext: omni.sensors.tiled-0.0.6] startup
# [2.602s] [ext: omni.sensors.nv.ids-1.1.0-isaac-1] startup
# [2.606s] [ext: omni.isaac.range_sensor-3.1.2] startup
# [2.617s] [ext: omni.usdphysics.ui-106.1.9] startup
# [2.637s] [ext: omni.physx.commands-106.1.9] startup
# [2.640s] [ext: omni.kit.manipulator.tool.snap-1.5.11] startup
# [2.645s] [ext: omni.isaac.sensor-12.9.1] startup
# [2.701s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [2.705s] [ext: omni.physx.ui-106.1.9] startup
# [2.745s] [ext: omni.isaac.quadruped-2.0.1] startup
# [2.752s] [ext: omni.kit.viewport.manipulator.transform-107.0.2] startup
# [2.754s] [ext: omni.physx.demos-106.1.9] startup
# [2.774s] [ext: omni.kit.property.physx-106.1.9] startup
# [2.839s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [2.841s] [ext: omni.kit.manipulator.prim.core-107.0.4] startup
# [2.847s] [ext: omni.fabric.commands-1.1.5] startup
# [2.849s] [ext: omni.physx.vehicle-106.1.9] startup
# [2.863s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [2.870s] [ext: omni.kit.manipulator.prim.fabric-107.0.3] startup
# [2.872s] [ext: omni.kit.manipulator.prim.usd-107.0.2] startup
# [2.873s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [2.875s] [ext: omni.kit.window.commands-0.2.6] startup
# [2.877s] [ext: omni.physx.camera-106.1.9] startup
# [2.886s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [2.889s] [ext: omni.kit.viewport.menubar.camera-107.0.2] startup
# [2.892s] [ext: omni.kit.manipulator.prim-107.0.0] startup
# [2.893s] [ext: omni.kit.manipulator.selection-106.0.1] startup
# [2.894s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [2.896s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [2.897s] [ext: omni.kit.viewport.menubar.render-106.1.1] startup
# [2.899s] [ext: omni.kit.viewport.menubar.settings-107.0.3] startup
# [2.902s] [ext: omni.physx.cct-106.1.9] startup
# [2.912s] [ext: omni.physx.graph-106.1.9] startup
# [2.928s] [ext: omni.physx.supportui-106.1.9] startup
# [2.951s] [ext: omni.physx.telemetry-106.1.9] startup
# [2.954s] [ext: omni.graph.ui_nodes-1.26.0] startup
# [2.958s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [2.958s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [2.960s] [ext: omni.kit.window.console-0.2.13] startup
# [2.969s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [2.971s] [ext: omni.kit.menu.create-1.0.16] startup
# [2.974s] [ext: omni.graph.bundle.action-2.4.1] startup
# [2.975s] [ext: omni.physx.bundle-106.1.9] startup
# [2.977s] [ext: omni.rtx.window.settings-0.6.17] startup
# [2.983s] [ext: omni.kit.window.status_bar-0.1.7] startup
# [2.987s] [ext: omni.kit.window.title-1.1.5] startup
# [2.988s] [ext: omni.replicator.isaac-1.15.2] startup
# [3.009s] [ext: omni.replicator.replicator_yaml-2.0.6] startup
# [3.032s] [ext: omni.rtx.settings.core-0.6.3] startup
# [3.041s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [3.046s] [ext: semantics.schema.editor-0.3.8] startup
# [3.052s] [ext: semantics.schema.property-1.0.4] startup
# [3.053s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [3.054s] [ext: omni.isaac.utils-1.0.1] startup
# [3.056s] [ext: omni.isaac.cloner-0.8.1] startup
# [3.058s] [ext: omni.importer.urdf-1.14.1] startup
# [3.090s] [ext: omni.kit.window.stats-0.1.6] startup
# [3.094s] [ext: omni.isaac.sim.python-4.2.0] startup
# [3.095s] Simulation App Starting
# [4.460s] app ready
# [4.933s] Simulation App Startup Complete
# Robot articulation successfully loaded: <omni.isaac.core.robots.robot.Robot object at 0x720125f457e0>
# Training Episodes:   0%|                               | 0/1000 [00:00<?, ?it/s]

# %%
simulation_app.close()
